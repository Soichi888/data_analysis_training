# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
titanic_df = pd.read_csv('train.csv')

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass    ...        Fare Cabin  Embarked
# 0            1         0       3    ...      7.2500   NaN         S
# 1            2         1       1    ...     71.2833   C85         C
# 2            3         1       3    ...      7.9250   NaN         S
# 3            4         1       1    ...     53.1000  C123         S
# 4            5         0       3    ...      8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /Users/soichitakahashi/SoichiDevelop/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/soichitakahashi/SoichiDevelop/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
sns.countplot('Sex', data = titanic_df)

# %% [markdown]
# The data of male and female passengers in the each classes

# %%
sns.countplot('Sex', data = titanic_df, hue = 'Pclass')

# %%
sns.countplot('Pclass', data = titanic_df, hue = 'Sex')

# %% [markdown]
# Createing new column to check passengers are children or adults

# %%
def male_female_child(passenger):
    age, sex = passenger
    if age < 16:
        return 'child'
    else:
        return sex
    
titanic_df['person'] = titanic_df[['Age','Sex']].apply(male_female_child,axis=1)

# %%
titanic_df.head(10)
# Out:
#    PassengerId  Survived  Pclass   ...   Cabin Embarked  person
# 0            1         0       3   ...     NaN        S    male
# 1            2         1       1   ...     C85        C  female
# 2            3         1       3   ...     NaN        S  female
# 3            4         1       1   ...    C123        S  female
# 4            5         0       3   ...     NaN        S    male
# 5            6         0       3   ...     NaN        Q    male
# 6            7         0       1   ...     E46        S    male
# 7            8         0       3   ...     NaN        S   child
# 8            9         1       3   ...     NaN        S  female
# 9           10         1       2   ...     NaN        C   child
#
# [10 rows x 13 columns]

# %% [markdown]
# The data of male, female, children in each classes

# %%
sns.countplot('Pclass', data = titanic_df, hue = 'person')

# %%
titanic_df['Age'].hist(bins=70)

# %%
titanic_df['Age'].mean()
# Out:
# 29.69911764705882

# %%
titanic_df['person'].value_counts()
# Out:
# male      537
# female    271
# child      83
# Name: person, dtype: int64

# %%
fig = sns.FacetGrid(titanic_df, hue='Sex', aspect=4)
fig.map(sns.kdeplot, 'Age', shade=True)
oldest = titanic_df['Age'].max()
fig.set(xlim=(0,oldest))
fig.add_legend()

# %%
fig = sns.FacetGrid(titanic_df, hue='person', aspect=4)
fig.map(sns.kdeplot, 'Age', shade=True)
oldest = titanic_df['Age'].max()
fig.set(xlim=(0,oldest))
fig.add_legend()

# %%
fig = sns.FacetGrid(titanic_df, hue='Pclass', aspect=4)
fig.map(sns.kdeplot, 'Age', shade=True)
oldest = titanic_df['Age'].max()
fig.set(xlim=(0,oldest))
fig.add_legend()

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass   ...   Cabin Embarked  person
# 0            1         0       3   ...     NaN        S    male
# 1            2         1       1   ...     C85        C  female
# 2            3         1       3   ...     NaN        S  female
# 3            4         1       1   ...    C123        S  female
# 4            5         0       3   ...     NaN        S    male
#
# [5 rows x 13 columns]

# %%
deck = titanic_df['Cabin'].dropna()

# %%
deck
# Out:
# 1              C85
# 3             C123
# 6              E46
# 10              G6
# 11            C103
# 21             D56
# 23              A6
# 27     C23 C25 C27
# 31             B78
# 52             D33
# 54             B30
# 55             C52
# 61             B28
# 62             C83
# 66             F33
# 75           F G73
# 88     C23 C25 C27
# 92             E31
# 96              A5
# 97         D10 D12
# 102            D26
# 110           C110
# 118        B58 B60
# 123           E101
# 124            D26
# 128          F E69
# 136            D47
# 137           C123
# 139            B86
# 148             F2
#           ...
# 751           E121
# 759            B77
# 763        B96 B98
# 765            D11
# 772            E77
# 776            F38
# 779             B3
# 781            B20
# 782             D6
# 789        B82 B84
# 796            D17
# 802        B96 B98
# 806            A36
# 809             E8
# 815           B102
# 820            B69
# ...

# %%
levels = []

for level in deck:
    levels.append(level[0])

# %%
cabin_df = DataFrame(levels)
cabin_df.columns = ['Cabin']

# %%
sns.countplot('Cabin', data=cabin_df, palette='winter', order=sorted(set(levels)))

# %%
cabin_df = cabin_df[cabin_df.Cabin != 'T']

# %%
sns.countplot('Cabin', data=cabin_df, palette='summer', order=sorted(set(cabin_df.Cabin)))

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass   ...   Cabin Embarked  person
# 0            1         0       3   ...     NaN        S    male
# 1            2         1       1   ...     C85        C  female
# 2            3         1       3   ...     NaN        S  female
# 3            4         1       1   ...    C123        S  female
# 4            5         0       3   ...     NaN        S    male
#
# [5 rows x 13 columns]

# %%
sns.countplot('Embarked', data=titanic_df, hue='Pclass')

# %%
from collections import Counter

# %%
Counter(titanic_df.Embarked)
# Out:
# Counter({'S': 644, 'C': 168, 'Q': 77, nan: 2})

# %%
titanic_df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
titanic_df['Alone'] = titanic_df.Parch + titanic_df.SibSp
titanic_df['Alone']
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       0
# 5       0
# 6       0
# 7       4
# 8       2
# 9       1
# 10      2
# 11      0
# 12      0
# 13      6
# 14      0
# 15      0
# 16      5
# 17      0
# 18      1
# 19      0
# 20      0
# 21      0
# 22      0
# 23      0
# 24      4
# 25      6
# 26      0
# 27      5
# 28      0
# 29      0
#        ..
# 861     1
# 862     0
# 863    10
# 864     0
# 865     0
# 866     1
# 867     0
# 868     0
# 869     2
# 870     0
# 871     2
# 872     0
# 873     0
# 874     1
# 875     0
# 876     0
# 877     0
# 878     0
# 879     1
# 880     1
# 881     0
# 882     0
# 883     0
# 884     0
# 885     5
# 886     0
# 887     0
# 888     3
# 889     0
# 890     0
# Name: Alone, Length: 891, dtype: int64

# %%
titanic_df['Alone'].loc[titanic_df['Alone']>0] = 'With Family'
titanic_df['Alone'].loc[titanic_df['Alone']==0] = 'Alone'
# Out:
# /Users/soichitakahashi/SoichiDevelop/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass     ...      Embarked  person        Alone
# 0            1         0       3     ...             S    male  With Family
# 1            2         1       1     ...             C  female  With Family
# 2            3         1       3     ...             S  female        Alone
# 3            4         1       1     ...             S  female  With Family
# 4            5         0       3     ...             S    male        Alone
#
# [5 rows x 14 columns]

# %%
sns.countplot('Alone', data = titanic_df, palette='Blues')

# %%
titanic_df['Survivers'] = titanic_df.Survived.map({0:'no', 1:'yes'})

# %%
sns.countplot('Survivers', data = titanic_df, palette='Set1')

# %%
sns.factorplot('Pclass', 'Survived', data=titanic_df, order=[1,2,3])

# %%
sns.factorplot('Pclass', 'Survived', hue='person', data=titanic_df, order=[1,2,3], aspect=2)

# %%
sns.lmplot('Age', 'Survived', data=titanic_df)

# %%
sns.lmplot('Age', 'Survived', hue='Pclass',data=titanic_df, palette='winter', hue_order=[1,2,3])

# %%
generations = [10,20,40,60,80]
sns.lmplot('Age', 'Survived', hue='Pclass',data=titanic_df, palette='winter', hue_order=[1,2,3], x_bins=generations)

# %%
sns.lmplot('Age', 'Survived', hue='Sex',data=titanic_df, palette='winter', x_bins=generations)
